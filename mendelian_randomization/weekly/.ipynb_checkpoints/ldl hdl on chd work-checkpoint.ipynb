# %% [markdown]
# ### Use this [guide](https://mrcieu.github.io/TwoSampleMR/articles/perform_mr.html)

# %%
library(TwoSampleMR)
# Out:
# TwoSampleMR version 0.5.6
# [>] New: Option to use non-European LD reference panels for clumping etc
# [>] Some studies temporarily quarantined to verify effect allele
# [>] See news(package='TwoSampleMR') and https://gwas.mrcieu.ac.uk for further details

# %% [markdown]
# ## notes
#
# * CHD
#     * Damage or disease in the heart's major blood vessels.
#     * The usual cause is the buildup of plaque. This causes coronary arteries to narrow, limiting blood flow to the heart.
#     * Coronary artery disease can range from no symptoms, to chest pain, to a heart attack.

# %% [markdown]
# ## updated method....read file in

# %%
# get hdl exposure data from local machine 
hdl_path = "C:\\Users\\Research\\Documents\\GitHub\\genomics\\mendelian_randomization\\misc\\tk\\april\\ldl hdl\\hdl_harmonized.tsv"
hdl_data_redux  <- read_exposure_data(
    filename = hdl_path,
    sep = "\t",
    snp_col = "hm_rsid",
    beta_col = "hm_beta",
    se_col ="standard_error",
    effect_allele_col = "hm_effect_allele",
    other_allele_col = "hm_other_allele",
    pval_col = "p_value",
    samplesize_col = "n"
)

ldl_path =  "C:\\Users\\Research\\Documents\\GitHub\\genomics\\mendelian_randomization\\misc\\tk\\april\\ldl hdl\\ldl_harmonized.tsv"
ldl_data_redux <- read_exposure_data(
    filename = ldl_path,
    sep = "\t",
    snp_col = "hm_rsid",
    beta_col = "hm_beta",
    se_col ="standard_error",
    effect_allele_col = "hm_effect_allele",
    other_allele_col = "hm_other_allele",
    pval_col = "p_value",
    samplesize_col = "n"
)

hdl_data_redux$SNP # learning the $ operator...R is so ew
# Out:
# Taking input= as a system command ('C:\Users\Research\Documents\GitHub\genomics\mendelian_randomization\misc\tk\april\ldl hdl\hdl_harmonized.tsv') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Warning message in (if (.Platform$OS.type == "unix") system else shell)(paste0("(", :
# "'(C:\Users\Research\Documents\GitHub\genomics\mendelian_randomization\misc\tk\april\ldl hdl\hdl_harmonized.tsv) > C:\Users\Research\AppData\Local\Temp\Rtmp88yyOc\file50643c4159f' execution failed with error code 1"
# Warning message in data.table::fread(filename, header = TRUE, sep = sep):
# "File 'C:\Users\Research\AppData\Local\Temp\Rtmp88yyOc\file50643c4159f' has size 0. Returning a NULL data.table."
# Error in format_data(as.data.frame(exposure_dat), type = "exposure", snps = NULL, : None of the specified columns present
# Traceback:
#
# 1. read_exposure_data(filename = hdl_path, sep = "\t", snp_col = "hm_rsid",
#  .     beta_col = "hm_beta", se_col = "standard_error", effect_allele_col = "hm_effect_allele",
#  .     other_allele_col = "hm_other_allele", pval_col = "p_value",
#  .     samplesize_col = "n")
# 2. format_data(as.data.frame(exposure_dat), type = "exposure", snps = NULL,
#  .     phenotype_col = phenotype_col, snp_col = snp_col, beta_col = beta_col,
#  .     se_col = se_col, eaf_col = eaf_col, effect_allele_col = effect_allele_col,
#  .     other_allele_col = other_allele_col, pval_col = pval_col,
#  .     units_col = units_col, ncase_col = ncase_col, ncontrol_col = ncontrol_col,
#  .     samplesize_col = samplesize_col, gene_col = gene_col, id_col = id_col,
#  .     min_pval = min_pval, log_pval = log_pval, chr_col = chr_col,
#  .     pos_col = pos_col)
# 3. stop("None of the specified columns present")

# %%
head(hdl_data_redux, 5)
# Out:
#   SNP       other_allele.exposure effect_allele.exposure beta.exposure
# 1 rs4747841 A                     G                       0.0026
# 2 rs4749917 C                     T                       0.0028
# 3 rs737656  A                     G                       0.0098
# 4 rs737657  A                     G                       0.0102
# 5 rs7086391 C                     T                      -0.0005
#   se.exposure samplesize.exposure pval.exposure exposure mr_keep.exposure
# 1 0.0048      93561               0.75380       exposure TRUE
# 2 0.0048      93561               0.72950       exposure TRUE
# 3 0.0049      94311               0.09234       exposure TRUE
# 4 0.0049      94311               0.09340       exposure TRUE
# 5 0.0062      94311               0.87230       exposure TRUE
#   pval_origin.exposure id.exposure eaf.exposure data_source.exposure
# 1 reported             wDxOH5      NA           textfile
# 2 reported             wDxOH5      NA           textfile
# 3 reported             wDxOH5      NA           textfile
# 4 reported             wDxOH5      NA           textfile
# 5 reported             wDxOH5      NA           textfile

# %%
# Get effects of instruments on outcome
outcome_dat <- extract_outcome_data(snps=hdl_data_redux$SNP, outcomes="ieu-a-7") # these outcomes are for coronary heart disease

# 

# Harmonise the exposure and outcome data
dat <- harmonise_data(exposure_dat, outcome_dat)
# Out:
# Extracting data for 2432351 SNP(s) from 1 GWAS(s)
#
# 1 of 1 outcomes
#
#  [>] 1 of 244 chunks
#
#  [>] 2 of 244 chunks
#
#  [>] 3 of 244 chunks
#
#  [>] 4 of 244 chunks
#
#  [>] 5 of 244 chunks
#
#  [>] 6 of 244 chunks
#
#  [>] 7 of 244 chunks
#
#  [>] 8 of 244 chunks
#
#  [>] 9 of 244 chunks
#
#  [>] 10 of 244 chunks
#
#  [>] 11 of 244 chunks
#
#  [>] 12 of 244 chunks
#
#  [>] 13 of 244 chunks
#
#  [>] 14 of 244 chunks
#
#  [>] 15 of 244 chunks
#
#  [>] 16 of 244 chunks
#
#  [>] 17 of 244 chunks
#
#  [>] 18 of 244 chunks
#
#  [>] 19 of 244 chunks
#
#  [>] 20 of 244 chunks
#
#  [>] 21 of 244 chunks
#
#  [>] 22 of 244 chunks
#
#  [>] 23 of 244 chunks
#
#  [>] 24 of 244 chunks
#
#  [>] 25 of 244 chunks
#
#  [>] 26 of 244 chunks
#
#  [>] 27 of 244 chunks
#
#  [>] 28 of 244 chunks
#
#  [>] 29 of 244 chunks
#
#  [>] 30 of 244 chunks
#
#  [>] 31 of 244 chunks
#
#  [>] 32 of 244 chunks
#
#  [>] 33 of 244 chunks
#
#  [>] 34 of 244 chunks
#
#  [>] 35 of 244 chunks
#
#  [>] 36 of 244 chunks
#
#  [>] 37 of 244 chunks
#
#  [>] 38 of 244 chunks
#
#  [>] 39 of 244 chunks
#
#  [>] 40 of 244 chunks
#
#  [>] 41 of 244 chunks
#
#  [>] 42 of 244 chunks
#
#  [>] 43 of 244 chunks
#
#  [>] 44 of 244 chunks
#
#  [>] 45 of 244 chunks
#
#  [>] 46 of 244 chunks
#
#  [>] 47 of 244 chunks
#
#  [>] 48 of 244 chunks
#
#  [>] 49 of 244 chunks
#
#  [>] 50 of 244 chunks
#
#  [>] 51 of 244 chunks
#
#  [>] 52 of 244 chunks
#
#  [>] 53 of 244 chunks
#
#  [>] 54 of 244 chunks
#
#  [>] 55 of 244 chunks
#
#  [>] 56 of 244 chunks
#
#  [>] 57 of 244 chunks
#
#  [>] 58 of 244 chunks
#
#  [>] 59 of 244 chunks
#
#  [>] 60 of 244 chunks
#
#  [>] 61 of 244 chunks
#
#  [>] 62 of 244 chunks
#
#  [>] 63 of 244 chunks
#
#  [>] 64 of 244 chunks
#
#  [>] 65 of 244 chunks
#
#  [>] 66 of 244 chunks
#
#  [>] 67 of 244 chunks
#
#  [>] 68 of 244 chunks
#
#  [>] 69 of 244 chunks
#
#  [>] 70 of 244 chunks
#
#  [>] 71 of 244 chunks
#
#  [>] 72 of 244 chunks
#
#  [>] 73 of 244 chunks
#
#  [>] 74 of 244 chunks
#
#  [>] 75 of 244 chunks
#
#  [>] 76 of 244 chunks
#
#  [>] 77 of 244 chunks
#
#  [>] 78 of 244 chunks
#
#  [>] 79 of 244 chunks
#
#  [>] 80 of 244 chunks
#
#  [>] 81 of 244 chunks
#
#  [>] 82 of 244 chunks
#
#  [>] 83 of 244 chunks
#
#  [>] 84 of 244 chunks
#
#  [>] 85 of 244 chunks
#
#  [>] 86 of 244 chunks
#
#  [>] 87 of 244 chunks
#
#  [>] 88 of 244 chunks
#
#  [>] 89 of 244 chunks
#
#  [>] 90 of 244 chunks
#
#  [>] 91 of 244 chunks
#
#  [>] 92 of 244 chunks
#
#  [>] 93 of 244 chunks
#
#  [>] 94 of 244 chunks
#
#  [>] 95 of 244 chunks
#
#  [>] 96 of 244 chunks
#
#  [>] 97 of 244 chunks
#
#  [>] 98 of 244 chunks
#
#  [>] 99 of 244 chunks
#
#  [>] 100 of 244 chunks
#
#  [>] 101 of 244 chunks
#
#  [>] 102 of 244 chunks
#
#  [>] 103 of 244 chunks
#
#  [>] 104 of 244 chunks
#
#  [>] 105 of 244 chunks
#
#  [>] 106 of 244 chunks
#
#  [>] 107 of 244 chunks
#
#  [>] 108 of 244 chunks
#
#  [>] 109 of 244 chunks
#
#  [>] 110 of 244 chunks
#
#  [>] 111 of 244 chunks
#
#  [>] 112 of 244 chunks
#
#  [>] 113 of 244 chunks
#
#  [>] 114 of 244 chunks
#
#  [>] 115 of 244 chunks
#
#  [>] 116 of 244 chunks
#
#  [>] 117 of 244 chunks
#
#  [>] 118 of 244 chunks
#
#  [>] 119 of 244 chunks
#
#  [>] 120 of 244 chunks
#
#  [>] 121 of 244 chunks
#
#  [>] 122 of 244 chunks
#
#  [>] 123 of 244 chunks
#
#  [>] 124 of 244 chunks
#
#  [>] 125 of 244 chunks
#
#  [>] 126 of 244 chunks
#
#  [>] 127 of 244 chunks
#
#  [>] 128 of 244 chunks
#
#  [>] 129 of 244 chunks
#
#  [>] 130 of 244 chunks
#
#  [>] 131 of 244 chunks
#
#  [>] 132 of 244 chunks
#
#  [>] 133 of 244 chunks
#
#  [>] 134 of 244 chunks
#
#  [>] 135 of 244 chunks
#
#  [>] 136 of 244 chunks
#
#  [>] 137 of 244 chunks
#
#  [>] 138 of 244 chunks
#
#  [>] 139 of 244 chunks
#
#  [>] 140 of 244 chunks
#
#  [>] 141 of 244 chunks
#
#  [>] 142 of 244 chunks
#
#  [>] 143 of 244 chunks
#
#  [>] 144 of 244 chunks
#
#  [>] 145 of 244 chunks
#
#  [>] 146 of 244 chunks
#
#  [>] 147 of 244 chunks
#
#  [>] 148 of 244 chunks
#
#  [>] 149 of 244 chunks
#
#  [>] 150 of 244 chunks
#
#  [>] 151 of 244 chunks
#
#  [>] 152 of 244 chunks
#
#  [>] 153 of 244 chunks
#
#  [>] 154 of 244 chunks
#
#  [>] 155 of 244 chunks
#
#  [>] 156 of 244 chunks
#
#  [>] 157 of 244 chunks
#
#  [>] 158 of 244 chunks
#
#  [>] 159 of 244 chunks
#
#  [>] 160 of 244 chunks
#
#  [>] 161 of 244 chunks
#
#  [>] 162 of 244 chunks
#
#  [>] 163 of 244 chunks
#
#  [>] 164 of 244 chunks
#
#  [>] 165 of 244 chunks
#
#  [>] 166 of 244 chunks
#
#  [>] 167 of 244 chunks
#
#  [>] 168 of 244 chunks
#
#  [>] 169 of 244 chunks
#
#  [>] 170 of 244 chunks
#
#  [>] 171 of 244 chunks
#
#  [>] 172 of 244 chunks
#
#  [>] 173 of 244 chunks
#
#  [>] 174 of 244 chunks
#
#  [>] 175 of 244 chunks
#
#  [>] 176 of 244 chunks
#
#  [>] 177 of 244 chunks
#
#  [>] 178 of 244 chunks
#
#  [>] 179 of 244 chunks
#
#  [>] 180 of 244 chunks
#
#  [>] 181 of 244 chunks
#
#  [>] 182 of 244 chunks
#
#  [>] 183 of 244 chunks
#
#  [>] 184 of 244 chunks
#
#  [>] 185 of 244 chunks
#
#  [>] 186 of 244 chunks
#
#  [>] 187 of 244 chunks
#
#  [>] 188 of 244 chunks
#
#  [>] 189 of 244 chunks
#
#  [>] 190 of 244 chunks
#
#  [>] 191 of 244 chunks
#
#  [>] 192 of 244 chunks
#
#  [>] 193 of 244 chunks
#
#  [>] 194 of 244 chunks
#
#  [>] 195 of 244 chunks
#
#  [>] 196 of 244 chunks
#
#  [>] 197 of 244 chunks
#
#  [>] 198 of 244 chunks
#
#  [>] 199 of 244 chunks
#
#  [>] 200 of 244 chunks
#
#  [>] 201 of 244 chunks
#
#  [>] 202 of 244 chunks
#
#  [>] 203 of 244 chunks
#
#  [>] 204 of 244 chunks
#
#  [>] 205 of 244 chunks
#
#  [>] 206 of 244 chunks
#
#  [>] 207 of 244 chunks
#
#  [>] 208 of 244 chunks
#
#  [>] 209 of 244 chunks
#
#  [>] 210 of 244 chunks
#
#  [>] 211 of 244 chunks
#
#  [>] 212 of 244 chunks
#
#  [>] 213 of 244 chunks
#
#  [>] 214 of 244 chunks
#
#  [>] 215 of 244 chunks
#
#  [>] 216 of 244 chunks
#
#  [>] 217 of 244 chunks
#
#  [>] 218 of 244 chunks
#
#  [>] 219 of 244 chunks
#
#  [>] 220 of 244 chunks
#
#  [>] 221 of 244 chunks
#
#  [>] 222 of 244 chunks
#
#  [>] 223 of 244 chunks
#
#  [>] 224 of 244 chunks
#
#  [>] 225 of 244 chunks
#
#  [>] 226 of 244 chunks
#
#  [>] 227 of 244 chunks
#
#  [>] 228 of 244 chunks
#
#  [>] 229 of 244 chunks
#
#  [>] 230 of 244 chunks
#
#  [>] 231 of 244 chunks
#
#  [>] 232 of 244 chunks
#
#  [>] 233 of 244 chunks
#
#  [>] 234 of 244 chunks
#
#  [>] 235 of 244 chunks
#
#  [>] 236 of 244 chunks
#
#  [>] 237 of 244 chunks
#
#  [>] 238 of 244 chunks
#
#  [>] 239 of 244 chunks
#
#  [>] 240 of 244 chunks
#
#  [>] 241 of 244 chunks
#
#  [>] 242 of 244 chunks
#
#  [>] 243 of 244 chunks
#
#  [>] 244 of 244 chunks
#
# Finding proxies for 28658 SNPs in outcome ieu-a-7
#
# Extracting data for 28658 SNP(s) from 1 GWAS(s)
#
# 1 of 1 outcomes
#
#  [>] 1 of 58 chunks
#
#  [>] 2 of 58 chunks
#
#  [>] 3 of 58 chunks
#
#  [>] 4 of 58 chunks
#
#  [>] 5 of 58 chunks
#
#  [>] 6 of 58 chunks
#
#  [>] 7 of 58 chunks
#
#  [>] 8 of 58 chunks
#
#  [>] 9 of 58 chunks
#
#  [>] 10 of 58 chunks
#
#  [>] 11 of 58 chunks
#
#  [>] 12 of 58 chunks
#
#  [>] 13 of 58 chunks
#
# Server code: 503; Server is possibly experiencing traffic, trying again...
#
# Server code: 503; Server is possibly experiencing traffic, trying again...
#
# Server code: 503; Server is possibly experiencing traffic, trying again...
#
# Server code: 503; Server is possibly experiencing traffic, trying again...
#
# Server code: 503; Server is possibly experiencing traffic, trying again...
#
# Server code: 503; Server is possibly experiencing traffic, trying again...
#
# Server error: 503
#
# Failed to retrieve results from server. See error status message in the returned object and contact the developers if the problem persists.
#
#  [>] 14 of 58 chunks
#
#  [>] 15 of 58 chunks
#
#  [>] 16 of 58 chunks
#
#  [>] 17 of 58 chunks
#
#  [>] 18 of 58 chunks
#
#  [>] 19 of 58 chunks
#
#  [>] 20 of 58 chunks
#
#  [>] 21 of 58 chunks
#
#  [>] 22 of 58 chunks
#
#  [>] 23 of 58 chunks
#
#  [>] 24 of 58 chunks
#
#  [>] 25 of 58 chunks
#
#  [>] 26 of 58 chunks
#
#  [>] 27 of 58 chunks
#
#  [>] 28 of 58 chunks
#
#  [>] 29 of 58 chunks
#
#  [>] 30 of 58 chunks
#
#  [>] 31 of 58 chunks
#
#  [>] 32 of 58 chunks
#
#  [>] 33 of 58 chunks
#
#  [>] 34 of 58 chunks
#
#  [>] 35 of 58 chunks
#
#  [>] 36 of 58 chunks
#
#  [>] 37 of 58 chunks
#
#  [>] 38 of 58 chunks
#
#  [>] 39 of 58 chunks
#
#  [>] 40 of 58 chunks
#
#  [>] 41 of 58 chunks
#
#  [>] 42 of 58 chunks
#
#  [>] 43 of 58 chunks
#
#  [>] 44 of 58 chunks
#
#  [>] 45 of 58 chunks
#
#  [>] 46 of 58 chunks
#
#  [>] 47 of 58 chunks
#
#  [>] 48 of 58 chunks
#
#  [>] 49 of 58 chunks
#
#  [>] 50 of 58 chunks
#
#  [>] 51 of 58 chunks
#
#  [>] 52 of 58 chunks
#
#  [>] 53 of 58 chunks
#
#  [>] 54 of 58 chunks
#
#  [>] 55 of 58 chunks
#
#  [>] 56 of 58 chunks
#
#  [>] 57 of 58 chunks
#
#  [>] 58 of 58 chunks
#
# Harmonising Body mass index || id:ieu-a-2 (ieu-a-2) and Coronary heart disease || id:ieu-a-7 (ieu-a-7)

# %%
res <- mr(dat)
# Out:
# Analysing 'ieu-a-2' on 'ieu-a-7'

# %% [markdown]
# ### plots

# %%
# scatter plot

# from docs: "# We can depict the relationship of the SNP effects on the exposure against the SNP effects on the outcome using a scatter plot."

p1 <- mr_scatter_plot(res, dat)
p1[[1]]
# Out:
# plot without title

# %%
# forest plot 
# from docs: "Use the mr_forest_plot() function to compare the MR estimates using the different MR methods against the single SNP tests."

res_single <- mr_singlesnp(dat)
p2 <- mr_forest_plot(res_single)
length(p2)
p2[[1]]
# Out:
# [1] 1
# Warning message:
# "Removed 1 rows containing missing values (geom_errorbarh)."
# Warning message:
# "Removed 1 rows containing missing values (geom_point)."
# plot without title

# %%
#leave one out plot
#Use the mr_leaveoneout_plot function to visualise the leave-one-out analysis:

res_loo <- mr_leaveoneout(dat)
p3 <- mr_leaveoneout_plot(res_loo)
p3[[1]]
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_errorbarh)."
# Warning message:
# "Removed 1 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# ## Random Notes
#
# * had to execute ```#write('PATH="${RTOOLS40_HOME}\\usr\\bin;${PATH}"', file = "~/.Renviron", append = TRUE)``` in a cell earlier after downloading and installing rtools so that I could build the repo from github
#
#
# #### things needed to perform MR (from two samp mr docs)
#
# * **Minimum Needed**
#     * SNP - rs ID
#     * beta - The effect size. If the trait is binary then log(OR) should be used
#     * se - The standard error of the effect size
#     * effect_allele - The allele of the SNP which has the effect marked in beta
#
# * **Other information that is useful**
#     * other_allele - The non-effect allele
#     * eaf - The effect allele frequency
#     * Phenotype - The name of the phenotype for which the SNP has an effect
#
# * **extra information**
#     * chr - Physical position of variant (chromosome)
#     * position - Physical position of variant (position)
#     * samplesize - Sample size for estimating the effect size
#     * ncase - Number of cases
#     * ncontrol - Number of controls
#     * pval - The P-value for the SNP’s association with the exposure
#     * units - The units in which the effects are presented
#     * gene - The gene or other annotation for the the SNP

# %%
## save dataframe to r-readable format
#import feather # don't forget that you need to first pip install feather-format
#path = 'my_data.feather'
#feather.write_dataframe(df, path)


## alternative is to just save df from pandas to csv and read csv in r with read.csv

library(feather)
path <- "my_data.feather"
df <- read_feather(path)

# write r data.frame object to RData file
#save(df, file = 'my_data.RData')
