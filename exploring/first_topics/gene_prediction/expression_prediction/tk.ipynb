# %% [markdown]
# # Notes
#
# ## Questions
# * So we know that when we read this feather file into a dataframe we get columns that correspond to samples...are these samples taken from lots of different people?
# * Do all of these genes code for proteins? According to this [nature article](https://www.nature.com/articles/d41586-018-05462-w), although we are not certain how many protein coding genes are out there, we think there are around "~ 21,000 protein-coding genes" in the human genome.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import preprocessing
from sklearn.decomposition import PCA


feather_df = pd.read_feather(r"C:\Users\Research\Documents\GitHub\genomics\exploring\first_topics\gene_prediction\expression_prediction\data\gene_expression_data.ftr")

data_df = feather_df.drop(columns=['ID_REF'])
'''
le = preprocessing.LabelEncoder()
le.fit(feather_df['ID_REF'])
gene_labels = le.transform(feather_df['ID_REF'])
print(le.classes_)
'''

data_df = data_df.drop(axis=0, index=22283)
data_df.T
# Out:
#              0       1       2        3       4        5       6       7      \
# GSM505327  12.4440  8.3774  6.7866  10.2851  5.9064   8.3767  8.0356  6.6745
# GSM505328  12.2005  7.8592  8.0963  10.4624  4.9582   9.2973  7.0581  6.4607
# GSM505329  12.6709  8.6762  7.4812  10.1887  5.2332   9.1721  8.6061  7.0932
# GSM505330  11.6619  8.2557  7.9923  10.7705  6.3296   9.3777  8.4776  6.5878
# GSM505331  11.8397  8.7971  7.8321  10.2869  5.8389   7.0841  7.3419  7.3167
# ...            ...     ...     ...      ...     ...      ...     ...     ...
# GSM505601  11.8023  7.8182  8.0532  11.2096  6.7603  10.0453  8.3714  4.8747
# GSM505602  11.4574  8.0488  8.2875  11.0754  6.8105   9.0332  8.4071  5.3538
# GSM505603  11.9181  7.3890  8.2965  10.8386  6.7350   8.9390  8.2275  5.9537
# GSM505604  11.7012  7.7375  8.5987  11.3588  7.5786   9.5624  8.5748  8.1305
# GSM505605  11.9795  7.9905  7.4312  10.9263  7.2528   9.4436  8.1317  5.5690
#
# ...

# %%
pca = PCA()
pca.fit(data_df)

explained_variances = pca.explained_variance_

plt.plot(np.arange(0, len(explained_variances), 1), explained_variances)
#plt.xscale('log')
plt.yscale('log')
